# %%
from tensorflow.keras import models, layers, activations, initializers

model = models.Sequential([
    layers.Input(shape=(256,256,3)),
    
    layers.Conv2D(16, (3,3), activation=activations.relu, padding='same'),
    layers.MaxPool2D((2,2)),
    
    layers.Conv2D(32, (3,3), activation=activations.relu, padding='same'),
    layers.MaxPool2D((2,2)),

    layers.Flatten(),
    layers.Dense(48, activation=activations.relu, kernel_initializer=initializers.RandomNormal()),
    layers.Dropout(0.3),
    layers.Dense(1, activation=activations.sigmoid, kernel_initializer=initializers.RandomNormal())

])

# %%
from tensorflow.keras import optimizers, losses, metrics

lr = 0.001

model.compile(
    optimizer=optimizers.Adam(
        learning_rate = lr
    ),
    loss= losses.BinaryCrossentropy(),
    metrics= [metrics.binary_accuracy]
)

# %%
from tensorflow.keras import utils

root = './Data'
batch_size = 64

train = utils.image_dataset_from_directory(
    directory=root,
    image_size=(256,256),
    validation_split = 0.2,
    subset= 'training',
    shuffle=True,
    seed= 1,
    label_mode='binary',
    batch_size= batch_size,
    color_mode='rgb'
)

test = utils.image_dataset_from_directory(
    directory=root,
    image_size=(256,256),
    validation_split = 0.2,
    subset= 'validation',
    shuffle=True,
    seed= 1,
    label_mode='binary',
    batch_size= batch_size,
    color_mode='rgb'
)
# Out:
# Found 2000 files belonging to 2 classes.
# Using 1600 files for training.
# Found 2000 files belonging to 2 classes.
# Using 400 files for validation.

# %%
from tensorflow.keras import callbacks

epochs = 64
patience = 8

model.fit(
    train,
    validation_data= test,
    epochs= epochs,
    verbose= True,
    callbacks= [
        callbacks.EarlyStopping(
            monitor= 'loss',
            restore_best_weights= True,
            patience= patience,
            mode= 'min'
        ),
        callbacks.ModelCheckpoint(
            filepath= './model.keras',
            save_best_only= True,
            save_weights_only=False,
            mode= 'min'
        )
    ]    
)
# Out:
# Epoch 1/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 18s 725ms/step - binary_accuracy: 1.0000 - loss: 1.1916e-04 - val_binary_accuracy: 0.6350 - val_loss: 2.4251
# Epoch 2/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 18s 725ms/step - binary_accuracy: 1.0000 - loss: 1.1031e-04 - val_binary_accuracy: 0.6350 - val_loss: 2.4480
# Epoch 3/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 18s 709ms/step - binary_accuracy: 1.0000 - loss: 1.0272e-04 - val_binary_accuracy: 0.6350 - val_loss: 2.4548
# Epoch 4/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - binary_accuracy: 1.0000 - loss: 9.4823e-05 - val_binary_accuracy: 0.6375 - val_loss: 2.4742
# Epoch 5/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - binary_accuracy: 1.0000 - loss: 8.9238e-05 - val_binary_accuracy: 0.6350 - val_loss: 2.4934
# Epoch 6/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - binary_accuracy: 1.0000 - loss: 8.2938e-05 - val_binary_accuracy: 0.6350 - val_loss: 2.4928
# Epoch 7/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - binary_accuracy: 1.0000 - loss: 7.8011e-05 - val_binary_accuracy: 0.6300 - val_loss: 2.5148
# Epoch 8/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - binary_accuracy: 1.0000 - loss: 7.3288e-05 - val_binary_accuracy: 0.6300 - val_loss: 2.5288
# Epoch 9/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 25s 982ms/step - binary_accuracy: 1.0000 - loss: 6.9008e-05 - val_binary_accuracy: 0.6300 - val_loss: 2.5396
# Epoch 10/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 870ms/step - binary_accuracy: 1.0000 - loss: 6.5211e-05 - val_binary_accuracy: 0.6325 - val_loss: 2.5458
# Epoch 11/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 41s 872ms/step - binary_accuracy: 1.0000 - loss: 6.1150e-05 - val_binary_accuracy: 0.6325 - val_loss: 2.5634
# Epoch 12/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 793ms/step - binary_accuracy: 1.0000 - loss: 5.7902e-05 - val_binary_accuracy: 0.6325 - val_loss: 2.5702
# Epoch 13/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 811ms/step - binary_accuracy: 1.0000 - loss: 5.4769e-05 - val_binary_accuracy: 0.6325 - val_loss: 2.5797
# Epoch 14/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - binary_accuracy: 1.0000 - loss: 5.1988e-05 - val_binary_accuracy: 0.6325 - val_loss: 2.5877
# Epoch 15/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - binary_accuracy: 1.0000 - loss: 4.9317e-05 - val_binary_accuracy: 0.6300 - val_loss: 2.6075
# Epoch 16/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - binary_accuracy: 1.0000 - loss: 4.7266e-05 - val_binary_accuracy: 0.6300 - val_loss: 2.6142
# Epoch 17/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - binary_accuracy: 1.0000 - loss: 4.4874e-05 - val_binary_accuracy: 0.6300 - val_loss: 2.6252
# Epoch 18/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - binary_accuracy: 1.0000 - loss: 4.2953e-05 - val_binary_accuracy: 0.6300 - val_loss: 2.6312
# Epoch 19/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - binary_accuracy: 1.0000 - loss: 4.0905e-05 - val_binary_accuracy: 0.6300 - val_loss: 2.6391
# Epoch 20/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 879ms/step - binary_accuracy: 1.0000 - loss: 3.9107e-05 - val_binary_accuracy: 0.6250 - val_loss: 2.6566
# Epoch 21/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 25s 987ms/step - binary_accuracy: 1.0000 - loss: 3.7874e-05 - val_binary_accuracy: 0.6325 - val_loss: 2.6525
# Epoch 22/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 782ms/step - binary_accuracy: 1.0000 - loss: 3.5826e-05 - val_binary_accuracy: 0.6250 - val_loss: 2.6677
# Epoch 23/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 794ms/step - binary_accuracy: 1.0000 - loss: 3.4331e-05 - val_binary_accuracy: 0.6275 - val_loss: 2.6701
# Epoch 24/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 915ms/step - binary_accuracy: 1.0000 - loss: 3.2948e-05 - val_binary_accuracy: 0.6175 - val_loss: 2.6831
# Epoch 25/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 800ms/step - binary_accuracy: 1.0000 - loss: 3.1764e-05 - val_binary_accuracy: 0.6225 - val_loss: 2.6859
# Epoch 26/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 774ms/step - binary_accuracy: 1.0000 - loss: 3.0298e-05 - val_binary_accuracy: 0.6250 - val_loss: 2.7022
# Epoch 27/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 786ms/step - binary_accuracy: 1.0000 - loss: 2.9154e-05 - val_binary_accuracy: 0.6250 - val_loss: 2.7100
# Epoch 28/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 18s 727ms/step - binary_accuracy: 1.0000 - loss: 2.7968e-05 - val_binary_accuracy: 0.6250 - val_loss: 2.7216
# Epoch 29/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - binary_accuracy: 1.0000 - loss: 2.7010e-05 - val_binary_accuracy: 0.6250 - val_loss: 2.7292
# Epoch 30/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - binary_accuracy: 1.0000 - loss: 2.5953e-05 - val_binary_accuracy: 0.6225 - val_loss: 2.7361
# Epoch 31/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 29s 708ms/step - binary_accuracy: 1.0000 - loss: 2.5006e-05 - val_binary_accuracy: 0.6225 - val_loss: 2.7452
# Epoch 32/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 723ms/step - binary_accuracy: 1.0000 - loss: 2.4210e-05 - val_binary_accuracy: 0.6225 - val_loss: 2.7514
# Epoch 33/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 18s 730ms/step - binary_accuracy: 1.0000 - loss: 2.3423e-05 - val_binary_accuracy: 0.6225 - val_loss: 2.7624
# Epoch 34/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 757ms/step - binary_accuracy: 1.0000 - loss: 2.2543e-05 - val_binary_accuracy: 0.6225 - val_loss: 2.7687
# Epoch 35/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 767ms/step - binary_accuracy: 1.0000 - loss: 2.1794e-05 - val_binary_accuracy: 0.6225 - val_loss: 2.7741
# Epoch 36/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 796ms/step - binary_accuracy: 1.0000 - loss: 2.1110e-05 - val_binary_accuracy: 0.6225 - val_loss: 2.7866
# Epoch 37/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 808ms/step - binary_accuracy: 1.0000 - loss: 2.0429e-05 - val_binary_accuracy: 0.6225 - val_loss: 2.7960
# Epoch 38/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 24s 971ms/step - binary_accuracy: 1.0000 - loss: 1.9736e-05 - val_binary_accuracy: 0.6200 - val_loss: 2.7981
# Epoch 39/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 840ms/step - binary_accuracy: 1.0000 - loss: 1.9159e-05 - val_binary_accuracy: 0.6225 - val_loss: 2.8079
# Epoch 40/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 797ms/step - binary_accuracy: 1.0000 - loss: 1.8543e-05 - val_binary_accuracy: 0.6175 - val_loss: 2.8190
# Epoch 41/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - binary_accuracy: 1.0000 - loss: 1.7969e-05 - val_binary_accuracy: 0.6175 - val_loss: 2.8235
# Epoch 42/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - binary_accuracy: 1.0000 - loss: 1.7480e-05 - val_binary_accuracy: 0.6200 - val_loss: 2.8195
# Epoch 43/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - binary_accuracy: 1.0000 - loss: 1.6911e-05 - val_binary_accuracy: 0.6200 - val_loss: 2.8344
# Epoch 44/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 823ms/step - binary_accuracy: 1.0000 - loss: 1.6321e-05 - val_binary_accuracy: 0.6175 - val_loss: 2.8400
# Epoch 45/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 796ms/step - binary_accuracy: 1.0000 - loss: 1.5813e-05 - val_binary_accuracy: 0.6175 - val_loss: 2.8448
# Epoch 46/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 878ms/step - binary_accuracy: 1.0000 - loss: 1.5363e-05 - val_binary_accuracy: 0.6200 - val_loss: 2.8560
# Epoch 47/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 779ms/step - binary_accuracy: 1.0000 - loss: 1.4949e-05 - val_binary_accuracy: 0.6175 - val_loss: 2.8588
# Epoch 48/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - binary_accuracy: 1.0000 - loss: 1.4482e-05 - val_binary_accuracy: 0.6175 - val_loss: 2.8695
# Epoch 49/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 828ms/step - binary_accuracy: 1.0000 - loss: 1.4114e-05 - val_binary_accuracy: 0.6200 - val_loss: 2.8674
# Epoch 50/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 829ms/step - binary_accuracy: 1.0000 - loss: 1.3720e-05 - val_binary_accuracy: 0.6175 - val_loss: 2.8821
# Epoch 51/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 791ms/step - binary_accuracy: 1.0000 - loss: 1.3345e-05 - val_binary_accuracy: 0.6175 - val_loss: 2.8857
# Epoch 52/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 778ms/step - binary_accuracy: 1.0000 - loss: 1.2980e-05 - val_binary_accuracy: 0.6175 - val_loss: 2.8929
# Epoch 53/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 846ms/step - binary_accuracy: 1.0000 - loss: 1.2609e-05 - val_binary_accuracy: 0.6175 - val_loss: 2.8972
# Epoch 54/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 780ms/step - binary_accuracy: 1.0000 - loss: 1.2252e-05 - val_binary_accuracy: 0.6175 - val_loss: 2.9056
# Epoch 55/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - binary_accuracy: 1.0000 - loss: 1.1911e-05 - val_binary_accuracy: 0.6175 - val_loss: 2.9041
# Epoch 56/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 814ms/step - binary_accuracy: 1.0000 - loss: 1.1579e-05 - val_binary_accuracy: 0.6150 - val_loss: 2.9191
# Epoch 57/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 795ms/step - binary_accuracy: 1.0000 - loss: 1.1208e-05 - val_binary_accuracy: 0.6175 - val_loss: 2.9281
# Epoch 58/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 799ms/step - binary_accuracy: 1.0000 - loss: 1.0914e-05 - val_binary_accuracy: 0.6150 - val_loss: 2.9345
# Epoch 59/64
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 773ms/step - binary_accuracy: 1.0000 - loss: 1.0588e-05 - val_binary_accuracy: 0.6150 - val_loss: 2.9391
# Epoch 60/64
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 6
#       3 epochs = 64
#       4 patience = 8
# ----> 6 model.fit(
#       7     train,
#       8     validation_data= test,
#       9     epochs= epochs,
#      10     verbose= True,
#      11     callbacks= [
#      12         callbacks.EarlyStopping(
#      13             monitor= 'loss',
#      14             restore_best_weights= True,
#      15             patience= patience,
#      16             mode= 'min'
#      17         ),
#      18         callbacks.ModelCheckpoint(
#      19             filepath= './model.keras',
#      20             save_best_only= True,
#      21             save_weights_only=False,
#      22             mode= 'min'
#      23         )
#      24     ]
#      25 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\backend\tensorflow\trainer.py:399, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     397 for begin_step, end_step, iterator in epoch_iterator:
#     398     callbacks.on_train_batch_begin(begin_step)
# --> 399     logs = self.train_function(iterator)
#     400     callbacks.on_train_batch_end(end_step, logs)
#     401     if self.stop_training:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\backend\tensorflow\trainer.py:241, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     237 def function(iterator):
#     238     if isinstance(
#     239         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240     ):
# --> 241         opt_outputs = multi_step_on_iterator(iterator)
#     242         if not opt_outputs.has_value():
#     243             raise StopIteration
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\eager\context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)   1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
